# %%
import pymongo
from pymongo import MongoClient
client = MongoClient('10.120.27.11', 27017)

# %%
db=client["text_mining"]

# %%
## db.pixnet.find({"type.0.二條城" :1});
## db.ptt_article.find({"type.0.二條城" :1});
## db.mobile01_article.find({"type.0.二條城" :1});
## db.odigo.find({"type.0.二條城" :1});

## db.pixnet.find({"type.1.三十三間堂" :1});
## db.ptt_article.find({"type.1.三十三間堂" :1});
## db.mobile01_article.find({"type.1.三十三間堂" :1});
## db.odigo.find({"type.1.三十三間堂" :1});

## db.pixnet.find({"type.2.千本鳥居" :1});
## db.ptt_article.find({"type.2.千本鳥居" :1});
## db.mobile01_article.find({"type.2.千本鳥居" :1});
## db.odigo.find({"type.2.千本鳥居" :1});

## db.pixnet.find({"type.3.平等院鳳凰堂" :1});
## db.ptt_article.find({"type.3.平等院鳳凰堂" :1});
## db.mobile01_article.find({"type.3.平等院鳳凰堂" :1});
## db.odigo.find({"type.3.平等院鳳凰堂" :1});

## db.pixnet.find({"type.4.京都御所" :1});
## db.ptt_article.find({"type.4.京都御所" :1});
## db.mobile01_article.find({"type.4.京都御所" :1});
## db.odigo.find({"type.4.京都御所" :1});

## db.pixnet.find({"type.5.京都塔" :1});
## db.ptt_article.find({"type.5.京都塔" :1});
## db.mobile01_article.find({"type.5.京都塔" :1});
## db.odigo.find({"type.5.京都塔" :1});

## db.pixnet.find({"type.6.金閣寺" :1});
## db.ptt_article.find({"type.6.金閣寺" :1});
## db.mobile01_article.find({"type.6.金閣寺" :1});
## db.odigo.find({"type.6.金閣寺" :1});

## db.pixnet.find({"type.7.清水寺" :1});
## db.ptt_article.find({"type.7.清水寺" :1});
## db.mobile01_article.find({"type.7.清水寺" :1});
## db.odigo.find({"type.7.清水寺" :1});

## db.pixnet.find({"type.8.渡月橋" :1});
## db.ptt_article.find({"type.8.渡月橋" :1});
## db.mobile01_article.find({"type.8.渡月橋" :1});
## db.odigo.find({"type.8.渡月橋" :1});

# %%
A = "ptt_article"
B = "mobile01_article"
C = "pixnet"
D = "odigo"

# %%
collection=db[A]
a1 = collection.find({"type.0.二條城" :1})
for aa1 in a1:
    try:
        collection=db["二條城"]
        collection.insert(aa1)
    except:
        pass
# Out:
# C:\Users\Java\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: DeprecationWarning: insert is deprecated. Use insert_one or insert_many instead.
#   import sys

# %%
collection=db[A]
a2 = collection.find({"type.1.三十三間堂" :1})
for aa2 in a2:
    try:
        collection=db["三十三間堂"]
        collection.insert(aa2)
    except:
        pass
# Out:
# C:\Users\Java\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning: insert is deprecated. Use insert_one or insert_many instead.

# %%
collection=db[A]
a3 = collection.find({"type.2.千本鳥居" :1})
for aa3 in a3:
    try:
        collection=db["千本鳥居"]
        collection.insert(aa3)
    except:
        pass
# Out:
# C:\Users\Java\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning: insert is deprecated. Use insert_one or insert_many instead.

# %%
collection=db[A]
a4 = collection.find({"type.3.平等院鳳凰堂" :1})
for aa4 in a4:
    try:
        collection=db["平等院鳳凰堂"]
        collection.insert(aa4)
    except:
        pass
# Out:
# C:\Users\Java\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning: insert is deprecated. Use insert_one or insert_many instead.

# %%
collection=db[A]
a5 = collection.find({"type.4.京都御所" :1})
for aa5 in a5:
    try:
        collection=db["京都御所"]
        collection.insert(aa5)
    except:
        pass
# Out:
# C:\Users\Java\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning: insert is deprecated. Use insert_one or insert_many instead.

# %%
collection=db[A]
a6 = collection.find({"type.5.京都塔" :1})
for aa6 in a6:
    try:
        collection=db["京都塔"]
        collection.insert(aa6)
    except:
        pass
# Out:
# C:\Users\Java\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning: insert is deprecated. Use insert_one or insert_many instead.

# %%
collection=db[A]
a7 = collection.find({"type.6.金閣寺" :1})
for aa7 in a7:
    try:
        collection=db["金閣寺"]
        collection.insert(aa7)
    except:
        pass
# Out:
# C:\Users\Java\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning: insert is deprecated. Use insert_one or insert_many instead.

# %%
collection=db[A]
a8 = collection.find({"type.7.清水寺" :1})
for aa8 in a8:
    try:
        collection=db["清水寺"]
        collection.insert(aa8)
    except:
        pass
# Out:
# C:\Users\Java\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning: insert is deprecated. Use insert_one or insert_many instead.

# %%
collection=db[A]
a9 = collection.find({"type.8.渡月橋" :1})
for aa9 in a9:
    try:
        collection=db["渡月橋"]
        collection.insert(aa9)
    except:
        pass
# Out:
# C:\Users\Java\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning: insert is deprecated. Use insert_one or insert_many instead.

# %%
AA = ["ptt_article", "mobile01_article", "pixnet", "odigo"]

# %%
for AAA in AA:
    collection=db[AAA]
    a1 = collection.find({"type.0.二條城" :1})
    for aa1 in a1:
        try:
            collection=db["二條城"]
            collection.insert(aa1)
        except:
            pass
    
    collection=db[AAA]
    a2 = collection.find({"type.1.三十三間堂" :1})
    for aa2 in a2:
        try:
            collection=db["三十三間堂"]
            collection.insert(aa2)
        except:
            pass
    
    collection=db[AAA]
    a3 = collection.find({"type.2.千本鳥居" :1})
    for aa3 in a3:
        try:
            collection=db["千本鳥居"]
            collection.insert(aa3)
        except:
            pass
        
    collection=db[AAA]
    a4 = collection.find({"type.3.平等院鳳凰堂" :1})
    for aa4 in a4:
        try:
            collection=db["平等院鳳凰堂"]
            collection.insert(aa4)
        except:
            pass  
        
    collection=db[AAA]
    a5 = collection.find({"type.4.京都御所" :1})
    for aa5 in a5:
        try:
            collection=db["京都御所"]
            collection.insert(aa5)
        except:
            pass
        
    collection=db[AAA]
    a6 = collection.find({"type.5.京都塔" :1})
    for aa6 in a6:
        try:
            collection=db["京都塔"]
            collection.insert(aa6)
        except:
            pass
        
    collection=db[AAA]
    a7 = collection.find({"type.6.金閣寺" :1})
    for aa7 in a7:
        try:
            collection=db["金閣寺"]
            collection.insert(aa7)
        except:
            pass
        
    collection=db[AAA]
    a8 = collection.find({"type.7.清水寺" :1})
    for aa8 in a8:
        try:
            collection=db["清水寺"]
            collection.insert(aa8)
        except:
            pass
        
    collection=db[AAA]
    a9 = collection.find({"type.8.渡月橋" :1})
    for aa9 in a9:
        try:
            collection=db["渡月橋"]
            collection.insert(aa9)
        except:
            pass
# Out:
# C:\Users\Java\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: DeprecationWarning: insert is deprecated. Use insert_one or insert_many instead.
#   import sys
# C:\Users\Java\Anaconda3\lib\site-packages\ipykernel_launcher.py:16: DeprecationWarning: insert is deprecated. Use insert_one or insert_many instead.
#   app.launch_new_instance()
# C:\Users\Java\Anaconda3\lib\site-packages\ipykernel_launcher.py:25: DeprecationWarning: insert is deprecated. Use insert_one or insert_many instead.
# C:\Users\Java\Anaconda3\lib\site-packages\ipykernel_launcher.py:34: DeprecationWarning: insert is deprecated. Use insert_one or insert_many instead.
# C:\Users\Java\Anaconda3\lib\site-packages\ipykernel_launcher.py:43: DeprecationWarning: insert is deprecated. Use insert_one or insert_many instead.
# C:\Users\Java\Anaconda3\lib\site-packages\ipykernel_launcher.py:52: DeprecationWarning: insert is deprecated. Use insert_one or insert_many instead.
# ...

# %%
db["二條城"].find().count()
# Out:
# 876

# %%
##after
db["二條城"].find().count()
# Out:
# 876

# %%
db["三十三間堂"].find().count()
# Out:
# 640

# %%
##after
db["三十三間堂"].find().count()
# Out:
# 640

# %%
db["千本鳥居"].find().count()
# Out:
# 4098

# %%
##after
db["千本鳥居"].find().count()
# Out:
# 4098

# %%
db["平等院鳳凰堂"].find().count()
# Out:
# 1178

# %%
##after
db["平等院鳳凰堂"].find().count()
# Out:
# 1178

# %%
db["京都御所"].find().count()
# Out:
# 868

# %%
##after
db["京都御所"].find().count()
# Out:
# 868

# %%
db["京都塔"].find().count()
# Out:
# 1028

# %%
##after
db["京都塔"].find().count()
# Out:
# 1028

# %%
db["金閣寺"].find().count()
# Out:
# 3555

# %%
##after
db["金閣寺"].find().count()
# Out:
# 3555

# %%
db["清水寺"].find().count()
# Out:
# 6203

# %%
##after
db["清水寺"].find().count()
# Out:
# 6203

# %%
db["渡月橋"].find().count()
# Out:
# 4311

# %%
##after
db["渡月橋"].find().count()
# Out:
# 4311

# %%
db["ptt_article"].find({"$and":[{"type.7.清水寺" :0},{"內文":{'$regex':"音羽山"}}]}).count()
# Out:
# 1

# %%
db["mobile01_article"].find({"$and":[{"type.7.清水寺" :0},{"內文":{'$regex':"音羽山"}}]}).count()
# Out:
# 0

# %%
db["pixnet"].find({"$and":[{"type.7.清水寺" :0},{"內文":{'$regex':"音羽山"}}]}).count()
# Out:
# 1

# %%
db["odigo"].find({"$and":[{"type.7.清水寺" :0},{"內文":{'$regex':"音羽山"}}]}).count()
# Out:
# 0

# %%
a = db["清水寺"].find({"內文":{'$regex':"包子"}},{"內文":1})

# %%
for b in a:
    print(b)
    print("--"*50)
# Out:
# {'_id': ObjectId('59a3779eaadaed210ce2c0a5'), '內文': '\n作者sakyk (堅．持)看板Japan_Travel標題[遊記] 帶媽媽京奈宇五天四夜自由行時間Sun Jan 15 17:50:14 2017\n\n第一次帶媽媽出國，安排京宇奈五天四夜自由行\n\n好讀圖文網誌：http://sofinawed.pixnet.net/blog/post/456177365\n\n---------------以下五天四夜文字很多的行程總覽---------------------------\n\nDAY1. 小港機場→關西機場→飯店Chcek in→錦市場&錦滿天宮→新京極商店街→飯店\n\nhttp://i.imgur.com/gjVkZXT.jpg\n\n之前自已出國都會選擇廉航，但帶著媽媽就乖乖選傳統航空，感覺比較保險。\n\n也有附機上餐，可以讓媽媽保持肚子不是餓的狀態。\n\n自已做的旅遊手冊，這五天的行程都全靠這本完美的手冊了。\n\n(照片是網路上抓的，若有侵權請告知，我再刪除)\n\n抵達關西機場入境後就先去買 ICOCA & HARUKA 車票及京都觀光一日券。\n\n到京都車站後，搭205號公車前往super hotel check in，因為15：00才可以入住\n\n我們時間有提早就先到錦市場附近晃晃。\n\n媽媽很喜歡錦市場乾乾淨淨，不會臭臭的，又可以試吃漬物。\n\n(她在那試吃的很開心，差點每樣都想買)\n\n晚餐就去吃我私心想吃的一蘭拉麵，媽媽的口味也很大眾，因為她也很愛!!\n\nhttp://i.imgur.com/kIaJj1S.jpg\nhttp://i.imgur.com/jpSKkS3.jpg\n\n因為搭早上七點的班機，所以媽媽略顯疲累，我們晚上7：00就到飯店休息，補充好體力\n\n迎接剩下的四天行程囉~\n\nDAY2. 飯店→染匠→清水寺周邊散策( 清水寺/二、三年坂/八重塔/石塀小路/祇園)\n\n預約10：30染匠和服體驗，早上還有很多時間可以優閒的吃早餐，打扮打扮再出門。\n\n從super hotel搭207號公車到「東山安井」站下車，再步行約5分到染匠。\n\n染匠的婆婆們很親切，在選擇和服時也會給點他們專業的建議，\n\n必竟第一次穿都會有選色的障礙
# ...

# %%
import re

# %%
collection=db[A]
a1 = collection.find({"type.0.二條城" :1})
print(a1.count())
for aa1 in a1:
    q = aa1["內文"].split("發信站: 批踢踢實業坊(ptt.cc)")[0]
    qq = re.findall("二條城",q)
    if len(qq) > 0:
        collection=db["二條城"]
        collection.insert(aa1)
# Out:
# 823
# C:\Users\Java\Anaconda3\lib\site-packages\ipykernel_launcher.py:9: DeprecationWarning: insert is deprecated. Use insert_one or insert_many instead.
#   if __name__ == '__main__':

# %%
collection=db[A]
a1 = collection.find({"type.1.三十三間堂" :1})
print(a1.count())
for aa1 in a1:
    q = aa1["內文"].split("發信站: 批踢踢實業坊(ptt.cc)")[0]
    qq = re.findall("三十三間堂",q)
    if len(qq) > 0:
        collection=db["三十三間堂"]
        collection.insert(aa1)
# Out:
# 572
# C:\Users\Java\Anaconda3\lib\site-packages\ipykernel_launcher.py:9: DeprecationWarning: insert is deprecated. Use insert_one or insert_many instead.
#   if __name__ == '__main__':

# %%
collection=db[A]
a1 = collection.find({"type.2.千本鳥居" :1})
print(a1.count())
for aa1 in a1:
    q = aa1["內文"].split("發信站: 批踢踢實業坊(ptt.cc)")[0]
    qq = re.findall("千本鳥居",q)
    if len(qq) > 0:
        collection=db["千本鳥居"]
        collection.insert(aa1)
# Out:
# 3812
# C:\Users\Java\Anaconda3\lib\site-packages\ipykernel_launcher.py:9: DeprecationWarning: insert is deprecated. Use insert_one or insert_many instead.
#   if __name__ == '__main__':

# %%
collection=db[A]
a1 = collection.find({"type.3.平等院鳳凰堂" :1})
print(a1.count())
for aa1 in a1:
    q = aa1["內文"].split("發信站: 批踢踢實業坊(ptt.cc)")[0]
    qq = re.findall("平等院鳳凰堂",q)
    if len(qq) > 0:
        collection=db["平等院鳳凰堂"]
        collection.insert(aa1)
# Out:
# 1091
# C:\Users\Java\Anaconda3\lib\site-packages\ipykernel_launcher.py:9: DeprecationWarning: insert is deprecated. Use insert_one or insert_many instead.
#   if __name__ == '__main__':

# %%
collection=db[A]
a1 = collection.find({"type.4.京都御所" :1})
print(a1.count())
for aa1 in a1:
    q = aa1["內文"].split("發信站: 批踢踢實業坊(ptt.cc)")[0]
    qq = re.findall("京都御所",q)
    if len(qq) > 0:
        collection=db["京都御所"]
        collection.insert(aa1)
# Out:
# 799
# C:\Users\Java\Anaconda3\lib\site-packages\ipykernel_launcher.py:9: DeprecationWarning: insert is deprecated. Use insert_one or insert_many instead.
#   if __name__ == '__main__':

# %%
collection=db[A]
a1 = collection.find({"type.5.京都塔" :1})
print(a1.count())
for aa1 in a1:
    q = aa1["內文"].split("發信站: 批踢踢實業坊(ptt.cc)")[0]
    qq = re.findall("京都塔",q)
    if len(qq) > 0:
        collection=db["京都塔"]
        collection.insert(aa1)
# Out:
# 960
# C:\Users\Java\Anaconda3\lib\site-packages\ipykernel_launcher.py:9: DeprecationWarning: insert is deprecated. Use insert_one or insert_many instead.
#   if __name__ == '__main__':

# %%
collection=db[A]
a1 = collection.find({"type.6.金閣寺" :1})
print(a1.count())
for aa1 in a1:
    q = aa1["內文"].split("發信站: 批踢踢實業坊(ptt.cc)")[0]
    qq = re.findall("金閣寺",q)
    if len(qq) > 0:
        collection=db["金閣寺"]
        collection.insert(aa1)
# Out:
# 3245
# C:\Users\Java\Anaconda3\lib\site-packages\ipykernel_launcher.py:9: DeprecationWarning: insert is deprecated. Use insert_one or insert_many instead.
#   if __name__ == '__main__':

# %%
collection=db[A]
a1 = collection.find({"type.7.清水寺" :1})
print(a1.count())
for aa1 in a1:
    q = aa1["內文"].split("發信站: 批踢踢實業坊(ptt.cc)")[0]
    qq = re.findall("清水寺",q)
    if len(qq) > 0:
        collection=db["清水寺"]
        collection.insert(aa1)
# Out:
# 5676
# C:\Users\Java\Anaconda3\lib\site-packages\ipykernel_launcher.py:9: DeprecationWarning: insert is deprecated. Use insert_one or insert_many instead.
#   if __name__ == '__main__':

# %%
collection=db[A]
a1 = collection.find({"type.8.渡月橋" :1})
print(a1.count())
for aa1 in a1:
    q = aa1["內文"].split("發信站: 批踢踢實業坊(ptt.cc)")[0]
    qq = re.findall("渡月橋",q)
    if len(qq) > 0:
        collection=db["渡月橋"]
        collection.insert(aa1)
# Out:
# 3907
# C:\Users\Java\Anaconda3\lib\site-packages\ipykernel_launcher.py:9: DeprecationWarning: insert is deprecated. Use insert_one or insert_many instead.
#   if __name__ == '__main__':

# %%
collection=db[A]
count = 0
a1 = collection.find({"type.8.渡月橋" :1})
for aa1 in a1:
    qq = re.findall("嵐山",str(aa1))
    if len(qq) == 0:
        count += 1
print(count)
# Out:
# 65

# %%
collection=db[B]
count = 0
a1 = collection.find({"type.8.渡月橋" :1})
for aa1 in a1:
    qq = re.findall("嵐山",str(aa1))

    if len(qq) == 0:
        count += 1
print(count)
# Out:
# 3

# %%
collection=db[C]
count = 0
a1 = collection.find({"type.8.渡月橋" :1})
for aa1 in a1:
    qq = re.findall("嵐山",str(aa1))

    if len(qq) == 0:
        count += 1
print(count)
# Out:
# 14

# %%
aaa = "BCDEFG"
aaa.split("A")[0]
# Out:
# 'BCDEFG'
