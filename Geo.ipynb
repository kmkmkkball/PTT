# %%
import requests
import time

# %%
focus = ["txt.txt"]

# %%
startT = time.time()
# src = "平等院鳳凰堂_Titlize" # DB 讀取來源 collection
filePath = "C:\\Users\\Java\\Desktop\\專題_textmining\\0910"
# focus = "TAGrestaurant" # 欲加強的目標
multi = 1  # 加強目標的權重
nowtime = time.strftime("%m%d")

# %%
site = []
for focuses in focus:
    g = open(filePath + "\\{}".format(focuses), 'r', encoding='utf-8')
    focused = g.readlines()
    # cnt=0
    for item in focused:
        site.append(item.strip())
    g.close()

# %% [markdown]
# ## Geocode

# %%
Geo = {}
for i in site:
    #print('https://maps.googleapis.com/maps/api/geocode/json?address={}&key=AIzaSyD9hu32E67dMlPefE2S7MPw3P4s5lDJtW8'.format(i+"京都"))
    res2 = requests.get("https://maps.googleapis.com/maps/api/geocode/json?address={}&key=AIzaSyCevPH3K5phyCsQJNNoCz5tvSiL4iQ87y4".format(i+"京都"))   
    Geo[i] = res2.json()

# %%
Geo
# Out:
# {'ALecomte': {'results': [], 'status': 'ZERO_RESULTS'},
#  'ATable': {'results': [{'address_components': [{'long_name': 'Kyoto',
#       'short_name': 'Kyoto',
#       'types': ['locality', 'political']},
#      {'long_name': 'Kyoto Prefecture',
#       'short_name': 'Kyoto Prefecture',
#       'types': ['administrative_area_level_1', 'political']},
#      {'long_name': 'Japan',
#       'short_name': 'JP',
#       'types': ['country', 'political']},
#      {'long_name': '604-0933',
#       'short_name': '604-0933',
#       'types': ['postal_code']}],
#     'formatted_address': 'Japan, 〒604-0933 Kyoto Prefecture, Kyoto, 中京区山本町４１０',
#     'geometry': {'location': {'lat': 35.0122602, 'lng': 135.7668111},
#      'location_type': 'GEOMETRIC_CENTER',
#      'viewport': {'northeast': {'lat': 35.0136091802915,
#        'lng': 135.7681600802915},
#       'southwest': {'lat': 35.0109112197085, 'lng': 135.7654621197085}}},
#     'partial_match': True,
# ...

# %%
# Geo["ATable"]['results'][0]['geometry']['location']
Geo["ATable"]['results'][0]['formatted_address']
# Out:
# 'Japan, 〒604-0933 Kyoto Prefecture, Kyoto, 中京区山本町４１０'

# %%
Geo3 = []
geo_name = []
geo_lo = []
geo_add = []
cnt = 0
for i in site:
    try:
        #print('https://maps.googleapis.com/maps/api/geocode/json?address={}&key=AIzaSyD9hu32E67dMlPefE2S7MPw3P4s5lDJtW8'.format(i+"京都"))
        res2 = requests.get("https://maps.googleapis.com/maps/api/geocode/json?address={}&key=AIzaSyD9hu32E67dMlPefE2S7MPw3P4s5lDJtW8".format(i+"京都"))   
        geo_name.append(i)
        geo_add.append(res2.json()['results'][0]['formatted_address'])
        geo_lo.append(res2.json()['results'][0]['geometry']['location'])
#         Geo2[i] = str(geo_list)
    except IndexError as e:
        geo_name.append('NA')
        geo_add.append('NA')
        geo_lo.append('NA')
        cnt += 1
        print(i); pass
# Out:
# TerraceSweetsMeal
# Demachiya
# Nagashima
# Pumpkin
# Takohachi
# 祇園小石甘味處
# Buran
# Okan
# Trio
# ElkCaf
# Tenso
# Hosho
# ALecomte
# Hosoi
# Yabusoba
# Gogoya
# 夕佳亭
# 夢京橋
# 普門閣

# %%
geo_name
# Out:
# ['一蘭拉麵',
#  '中村藤吉',
#  '志津香',
#  '茶寮都路里',
#  '一風堂',
#  '名代豬排',
#  '伊藤久右衛門',
#  '山元麵藏',
#  'Yojiya',
#  '鳥岩樓',
#  '三忠',
#  '金龍拉麵',
#  'Okina',
#  'Fresco',
#  '鳥貴族',
#  '廣川',
#  '進進堂',
#  '六傳屋',
#  'Pin',
#  '三嶋亭',
#  '東洋亭',
#  '順正',
#  '古都芋',
#  '鍵善良房',
#  '京都拉麵小路',
#  '天周',
#  '京都勝牛',
#  '丸久小山園',
#  '壹錢洋食',
#  '一保堂',
#  'Arabica咖啡',
#  '本格燒肉',
#  '十二段家',
#  '大起水產迴轉壽司',
#  'Maruki麵包',
#  '松之助',
#  '老松',
#  'Arinco',
#  'Sagan',
#  '博多一幸舍',
#  '六盛茶庭',
#  'Porta地下街',
#  '洛匠',
#  'Hida',
#  '嵐山辨慶',
#  'MisterDonut',
#  '清水順正',
#  '柚子元',
#  '茂庵',
#  '六曜社',
#  '虎屋',
#  '然花抄院',
#  'InodaCoffee',
#  '本家第一旭',
#  'YojiyaCafe',
#  '猪一',
#  '辻利抹茶',
#  '高安',
#  '本家尾張屋',
#  'Kfc',
#  '小宝',
#  'Yayoiken',
#  '鳴門鯛燒',
#  'Manneken',
#  '八代目儀兵衛',
#  '前田咖啡',
#  'FirstKitchen',
#  'Kura壽司',
#  '三嶋亭本店',
#  '天天有',
#  '瓢亭',
#  'Sushiro',
#  '米福',
#  '小川咖啡',
#  '日月庵',
#  'Awomb',
#  '新福菜館',
#  '八坂圓堂',
#  'PatisserieS',
#  'RedRock',
#  '保田沾麵',
#  '紫藏',
#  '春鹿釀造元',
#  '露庵菊乃井',
#  'IkinariSteak',
# ...

# %%
import re

# %%
len(geo_lo)
# Out:
# 701

# %%
len(geo_add)
# Out:
# 701

# %%
len(geo_name)
# Out:
# 720

# %%
len(geo_lo)
# Out:
# 701

# %%
geo_add
# Out:
# ['Japan, 〒604-8041 Kyoto Prefecture, Kyoto, Nakagyo Ward, 蛸薬師OKIビル 蛸薬師通新京極東入裏寺町598番地',
#  'Japan, 〒600-8555 Kyoto Prefecture, Kyoto, Shimogyo Ward, スバコ・ジェイアール京都伊勢丹3F 烏丸通塩小路下ル東塩小路町',
#  'Japan, 〒630-8115 Nara Prefecture, Nara, 大宮町４−249−4',
#  'Japan, 〒605-0074 Kyoto Prefecture, Kyoto, Higashiyama Ward, 四条通祇園町南側573-3',
#  'Japan, 〒604-8143 Kyoto Prefecture, Kyoto, Nakagyo Ward, 東洞院錦小路東入ル 阪東屋町653-1 錦ビル1F',
#  'Japan, 〒604-8205 Kyoto Prefecture, Kyoto, Nakagyo Ward, 三条通寺町東入石橋町16',
#  'Japan, 〒600-8216 Kyoto Prefecture, Kyoto, Shimogyo Ward, Higashishiokojicho, 579番地 1F',
#  'Japan, 〒606-8334 Kyoto Prefecture, Kyoto, Sakyo Ward, Okazaki Minamigoshocho, 34',
#  'Japan, 〒604-0924 Kyoto Prefecture, Kyoto, Nakagyo Ward, 河原町通二条下ル一之船入町５３８番地',
#  'Japan, 〒602-8446 Kyoto Prefecture, Kyoto, Kamigyo Ward, 五辻通智恵光院西入ル五辻町75',
#  'Japan, 〒616-8375 Kyoto Prefecture, Kyoto, 右京区嵯峨天龍寺立石町２−１',
#  'Japan, 〒613-0024 Kyoto Prefecture, Kuse District, 久御山町森南大内156−1',
# ...

# %%
res2 = requests.get("https://maps.googleapis.com/maps/api/geocode/json?address=伏見稻荷大社&key=AIzaSyD9hu32E67dMlPefE2S7MPw3P4s5lDJtW8")

# %%
res2.json()['results'][0]['geometry']['location']
# Out:
# {'lat': 34.9671402, 'lng': 135.7726717}

# %%
Geo2["順正"]
# Out:
# "['Japan, 〒606-8437 Kyoto Prefecture, Kyoto, Sakyo Ward, 南禅寺草川町６０', {'lat': 35.011292, 'lng': 135.790069}]"

# %%
with open(filePath + "\\9spot_coordinate.txt", 'w', encoding='utf-8') as f:
    f.write(str(Geo).replace("},","},\n"))

# %%
str(Geo).replace("},","},\n")
# Out:
# "{'夢館': {'lat': 34.9964915, 'lng': 135.7615001},\n '岡本和服': {'lat': 34.99621570000001, 'lng': 135.7814394},\n '染匠': {'lat': 34.999527, 'lng': 135.7789889},\n 'Tekuteku': {'lat': 34.994337, 'lng': 135.7259805},\n '和櫻': {'lat': 35.005773, 'lng': 135.7778314},\n '振袖': {'lat': 35.006125, 'lng': 135.758583},\n '花之繪姿': {'lat': 34.9955991, 'lng': 135.7792813},\n '夢京都': {'lat': 35.004352, 'lng': 135.77761},\n '長羽織': {'lat': 35.001159, 'lng': 135.760052},\n 'RentalOne': {'lat': 35.005198, 'lng': 135.769441},\n '遊月': {'lat': 35.0116863, 'lng': 135.6786338},\n '紅姬': {'lat': 35.0141727, 'lng': 135.6775517},\n '和凜': {'lat': 34.998715, 'lng': 135.760415},\n '': {'lat': 35.0116363, 'lng': 135.7680294},\n '清水寺': {'lat': 34.9948561, 'lng': 135.7850463},\n '嵐山': {'lat': 35.009449, 'lng': 135.666773},\n '金閣寺': {'lat': 35.03937, 'lng': 135.7292431},\n '伏見稻荷': {'lat': 34.96879150000001, 'lng': 135.7691659},\n '祇園': {'lat': 35.0037279, 'lng': 135.7742612},\n '伏見稻荷大社': {'lat': 34.9671402, 'lng': 135.7726717
# ...

# %%
geo = {}
for i in site:
    res2 = requests.get("https://maps.googleapis.com/maps/api/geocode/json?address={}&key=AIzaSyCevPH3K5phyCsQJNNoCz5tvSiL4iQ87y4".format(i+"京都"))   
    geo[i] = res2.json()['results'][0]['geometry']['location']
